# %% [markdown]
# PERSISTANT LTM implementation for using POSTGRES - dockercompose file

# %%
! pip install -U "psycopg[binary,pool]" langgraph langgraph-checkpoint-postgres
# Out:
# Requirement already satisfied: langgraph in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (1.2.8)
# Collecting langgraph
#   Using cached langgraph-1.2.9-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: langgraph-checkpoint-postgres in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (3.1.0)
# Requirement already satisfied: psycopg[binary,pool] in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (3.3.4)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from psycopg[binary,pool]) (4.16.0)
# Requirement already satisfied: tzdata in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from psycopg[binary,pool]) (2026.3)
# Requirement already satisfied: psycopg-binary==3.3.4 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from psycopg[binary,pool]) (3.3.4)
# Requirement already satisfied: psycopg-pool in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from psycopg[binary,pool]) (3.3.1)
# Requirement already satisfied: langchain-core<2,>=1.4.7 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from langgraph) (1.4.8)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from langgraph) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from langgraph) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from langgraph) (0.4.2)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from langgraph) (2.13.4)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from langgraph) (3.8.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from langgraph-checkpoint-postgres) (3.11.9)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (0.9.8)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (0.16.2)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.28.1)
# Requirement already satisfied: websockets<16,>=14 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (15.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from pydantic>=2.7.4->langgraph) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: anyio in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (4.14.1)
# Requirement already satisfied: certifi in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (1.0.9)
# Requirement already satisfied: idna in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2,>=1.4.7->langgraph) (3.1.1)
# Requirement already satisfied: distro>=1.7.0 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (3.4.8)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\lenovo\onedrive\desktop\langgraph practice\myenv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (2.7.0)
# Using cached langgraph-1.2.9-py3-none-any.whl (247 kB)
# Installing collected packages: langgraph
#   Attempting uninstall: langgraph
#     Found existing installation: langgraph 1.2.8
#     Uninstalling langgraph-1.2.8:
#       Successfully uninstalled langgraph-1.2.8
# Successfully installed langgraph-1.2.9
# [notice] A new release of pip is available: 24.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dotenv import load_dotenv
load_dotenv()

import uuid
from typing import List
from pydantic import BaseModel, Field

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import SystemMessage
from langchain_core.runnables import RunnableConfig

from langgraph.graph import StateGraph, START, END, MessagesState
from langgraph.store.postgres import PostgresStore
from langgraph.store.base import BaseStore

# %%
# 2) System prompt

SYSTEM_PROMPT_TEMPLATE = """You are a helpful assistant with memory capabilities.
If user-specific memory is available, use it to personalize 
your responses based on what you know about the user.

Your goal is to provide relevant, friendly, and tailored 
assistance that reflects the user’s preferences, context, and past interactions.

If the user’s name or relevant personal context is available, always personalize your responses by:
    – Always Address the user by name (e.g., "Sure, Nitish...") when appropriate
    – Referencing known projects, tools, or preferences (e.g., "your MCP server python based project")
    – Adjusting the tone to feel friendly, natural, and directly aimed at the user

Avoid generic phrasing when personalization is possible.

Use personalization especially in:
    – Greetings and transitions
    – Help or guidance tailored to tools and frameworks the user uses
    – Follow-up messages that continue from past context

Always ensure that personalization is based only on known user details and not assumed.

In the end suggest 3 relevant further questions based on the current response and user profile

The user’s memory (which may be empty) is provided as: {user_details_content}
"""

# %%
# 3) Memory extraction LLM

memory_llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)

# %%
class MemoryItem(BaseModel):
    text: str = Field(description="Atomic user memory")
    is_new: bool = Field(description="True if new, false if duplicate")

# %%
class MemoryDecision(BaseModel):
    should_write: bool
    memories: List[MemoryItem] = Field(default_factory=list)

# %%
memory_extractor = memory_llm.with_structured_output(MemoryDecision)

# %%
MEMORY_PROMPT = """
You are responsible for updating and maintaining accurate user memory.

CURRENT USER DETAILS (existing memories):
{user_details_content}

TASK:
- Review the user's latest message.
- Extract user-specific info worth storing long-term (identity, stable preferences, ongoing projects/goals).
- For each extracted item, set is_new=true ONLY if it adds NEW information compared to CURRENT USER DETAILS.
- If it is basically the same meaning as something already present, set is_new=false.
- Keep each memory as a short atomic sentence.
- No speculation; only facts stated by the user.
- If there is nothing memory-worthy, return should_write=false and an empty list.
"""

# %%
# 3) Nodes

def remember_node(state: MessagesState, config: RunnableConfig, *, store: BaseStore):
    user_id = config["configurable"]["user_id"]
    ns = ("user", user_id, "details")

    # existing memory (all items under namespace)
    items = store.search(ns)
    existing = "\n".join(it.value.get("data", "") for it in items) if items else "(empty)"

    # latest user message
    last_text = state["messages"][-1].content

    decision: MemoryDecision = memory_extractor.invoke(
        [
            SystemMessage(content=MEMORY_PROMPT.format(user_details_content=existing)),
            {"role": "user", "content": last_text},
        ]
    )

    if decision.should_write:
        for mem in decision.memories:
            if mem.is_new and mem.text.strip():
                store.put(ns, str(uuid.uuid4()), {"data": mem.text.strip()})

    return {}

# %%
chat_llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
def chat_node(state: MessagesState, config: RunnableConfig, *, store: BaseStore):
    user_id = config["configurable"]["user_id"]
    ns = ("user", user_id, "details")

    items = store.search(ns)
    user_details = "\n".join(it.value.get("data", "") for it in items) if items else ""

    system_msg = SystemMessage(
        content=SYSTEM_PROMPT_TEMPLATE.format(user_details_content=user_details or "(empty)")
    )

    response = chat_llm.invoke([system_msg] + state["messages"])
    return {"messages": [response]}

# %%
# 4) Build graph

builder = StateGraph(MessagesState)
builder.add_node("remember", remember_node)
builder.add_node("chat", chat_node)
builder.add_edge(START, "remember")
builder.add_edge("remember", "chat")
builder.add_edge("chat", END)

# %%
# 5) Use PostgresStore (PERSISTENT LTM)

DB_URI = "postgresql://postgres:postgres@localhost:5442/postgres?sslmode=disable"

with PostgresStore.from_conn_string(DB_URI) as store:
    # IMPORTANT: run ONCE the first time you use this database
    store.setup()

    graph = builder.compile(store=store)

    config = {"configurable": {"user_id": "u1"}}

    graph.invoke({"messages": [{"role": "user", "content": "Hi, my name is Nazia"}]}, config)
    graph.invoke({"messages": [{"role": "user", "content": "Iam a Software Developer"}]}, config)

    out = graph.invoke({"messages": [{"role": "user", "content": "Explain GenAI simply"}]}, config)
    print(out["messages"][-1].content)

    print("\n--- Stored Memories (from Postgres) ---")
    for it in store.search(("user", "u1", "details")):
        print(it.value["data"])

# %% [markdown]
# CHECKING PERSISTANCE

# %%
from langgraph.store.postgres import PostgresStore

DB_URI = "postgresql://postgres:postgres@localhost:5442/postgres?sslmode=disable"

with PostgresStore.from_conn_string(DB_URI) as store:
    ns = ("user", "u1", "details")
    items = store.search(ns)

for it in items:
    print(it.value["data"])
